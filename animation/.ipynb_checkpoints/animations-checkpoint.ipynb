# %%
import numpy as np
import pandas as pd
from mplsoccer import Pitch, VerticalPitch
import matplotlib.pyplot as plt
from matplotlib import animation

# %%
# Load Full Tracking Data
tracking_df = pd.read_json('../data/matches/1886347/1886347_tracking_extrapolated.jsonl', lines=True)
raw_df =pd.json_normalize(tracking_df.to_dict('records'), 'player_data',
                         ['frame','timestamp','period','possession','ball_data'])

# Clean Tracking Data
raw_df['possession_player_id'] = raw_df['possession'].apply(lambda x: x.get('player_id'))
raw_df['possession_group'] = raw_df['possession'].apply(lambda x: x.get('group'))
raw_df[['ball_x','ball_y','ball_z','is_detected_ball']]=pd.json_normalize(raw_df.ball_data)
raw_df = raw_df.drop(columns=['possession','ball_data'])
raw_df.head()
# Out:
#        x      y  player_id  is_detected frame  timestamp period  \
# 0 -39.63  -0.08      51009        False    10 2026-03-31    1.0
# 1 -19.21  -9.18     176224         True    10 2026-03-31    1.0
# 2 -21.83   0.47      51649         True    10 2026-03-31    1.0
# 3  -1.16 -32.47      50983         True    10 2026-03-31    1.0
# 4 -18.88  15.73     735578         True    10 2026-03-31    1.0
#
#    possession_player_id possession_group  ball_x  ball_y  ball_z  \
# 0                   NaN             None    0.32    0.38    0.13
# 1                   NaN             None    0.32    0.38    0.13
# 2                   NaN             None    0.32    0.38    0.13
# 3                   NaN             None    0.32    0.38    0.13
# 4                   NaN             None    0.32    0.38    0.13
#
#    is_detected_ball
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True

# %%
# convert timestamp to seconds
raw_df["timestamp"] = list(map(lambda x: x.hour * 3600 + x.minute * 60 + x.second, raw_df["timestamp"]))

# %%
print(raw_df["timestamp"].describe())
# Out:
# count    956076.000000
# mean       2686.454232
# std        1655.736591
# min           0.000000
# 25%        1258.000000
# 50%        2634.000000
# 75%        4055.000000
# max        5823.000000
# Name: timestamp, dtype: float64

# %%
raw_df.head()
# Out:
#        x      y  player_id  is_detected frame  timestamp period  \
# 0 -39.63  -0.08      51009        False    10          0    1.0
# 1 -19.21  -9.18     176224         True    10          0    1.0
# 2 -21.83   0.47      51649         True    10          0    1.0
# 3  -1.16 -32.47      50983         True    10          0    1.0
# 4 -18.88  15.73     735578         True    10          0    1.0
#
#    possession_player_id possession_group  ball_x  ball_y  ball_z  \
# 0                   NaN             None    0.32    0.38    0.13
# 1                   NaN             None    0.32    0.38    0.13
# 2                   NaN             None    0.32    0.38    0.13
# 3                   NaN             None    0.32    0.38    0.13
# 4                   NaN             None    0.32    0.38    0.13
#
#    is_detected_ball
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True

# %%
print(raw_df[raw_df["frame"]==3125])
# Out:
#            x      y  player_id  is_detected frame  timestamp period  \
# 65758 -34.75  -6.15      51009        False  3125        311    1.0
# 65759  -2.54 -29.26     176224        False  3125        311    1.0
# 65760  -7.26 -15.47      51649        False  3125        311    1.0
# 65761  13.17 -29.27      50983        False  3125        311    1.0
# 65762  -3.59  -2.61     735578        False  3125        311    1.0
# 65763  10.08 -23.97      50978        False  3125        311    1.0
# 65764   3.59 -19.32     735574        False  3125        311    1.0
# 65765  20.28  -9.43     795507        False  3125        311    1.0
# 65766  21.51 -30.14     795505        False  3125        311    1.0
# 65767  12.05   1.90     735573        False  3125        311    1.0
# 65768  20.46 -19.35     966120        False  3125        311    1.0
# 65769  43.61  -2.87     285188        False  3125        311    1.0
# 65770  18.96 -10.61      51667        False  3125        311    1.0
# ...

# %%
# load dynamic data for team names
dynamic_df_full = pd.read_csv('../data/matches/1886347/1886347_dynamic_events.csv')
        
dynamic_df = dynamic_df_full[["player_id", "team_id"]].drop_duplicates().reset_index().drop(columns=["index"])

# %%
print(dynamic_df)
# Out:
#     player_id  team_id
# 0      966120     1805
# 1       51649     1805
# 2      735574     1805
# 3      735578     1805
# 4       50951     4177
# 5       50978     1805
# 6      795507     1805
# 7      735573     1805
# 8       38673     4177
# 9       33697     4177
# 10     133498     4177
# 11     965685     4177
# 12     795505     1805
# 13      23418     4177
# 14      50983     1805
# 15      51009     1805
# 16     176224     1805
# 17     133501     4177
# 18      51713     4177
# 19      14736     4177
# 20      51667     4177
# 21     285188     4177
# 22     560992     1805
# 23     795506     1805
# 24      43829     4177
# 25     163972     4177
# 26     797297     1805
# 27     800320     1805
# 28      31147     4177

# %%
full_df = raw_df.merge(dynamic_df, left_on="player_id", right_on="player_id")
full_df.head()
# Out:
#        x      y  player_id  is_detected frame  timestamp period  \
# 0 -39.63  -0.08      51009        False    10          0    1.0
# 1 -19.21  -9.18     176224         True    10          0    1.0
# 2 -21.83   0.47      51649         True    10          0    1.0
# 3  -1.16 -32.47      50983         True    10          0    1.0
# 4 -18.88  15.73     735578         True    10          0    1.0
#
#    possession_player_id possession_group  ball_x  ball_y  ball_z  \
# 0                   NaN             None    0.32    0.38    0.13
# 1                   NaN             None    0.32    0.38    0.13
# 2                   NaN             None    0.32    0.38    0.13
# 3                   NaN             None    0.32    0.38    0.13
# 4                   NaN             None    0.32    0.38    0.13
#
#    is_detected_ball  team_id
# 0              True     1805
# 1              True     1805
# 2              True     1805
# 3              True     1805
# 4              True     1805

# %%
# want the home team to be one
full_df["team_id"] = list(map(lambda test: 1 if test==1805 else 0, full_df["team_id"]))

# %%
full_df.head()
# Out:
#        x      y  player_id  is_detected frame  timestamp period  \
# 0 -39.63  -0.08      51009        False    10          0    1.0
# 1 -19.21  -9.18     176224         True    10          0    1.0
# 2 -21.83   0.47      51649         True    10          0    1.0
# 3  -1.16 -32.47      50983         True    10          0    1.0
# 4 -18.88  15.73     735578         True    10          0    1.0
#
#    possession_player_id possession_group  ball_x  ball_y  ball_z  \
# 0                   NaN             None    0.32    0.38    0.13
# 1                   NaN             None    0.32    0.38    0.13
# 2                   NaN             None    0.32    0.38    0.13
# 3                   NaN             None    0.32    0.38    0.13
# 4                   NaN             None    0.32    0.38    0.13
#
#    is_detected_ball  team_id
# 0              True        1
# 1              True        1
# 2              True        1
# 3              True        1
# 4              True        1

# %%
# drop columns not necessary for home and away player locations
drop = ["ball_x", "ball_y", "ball_z", "is_detected_ball"] 
df_away = full_df[full_df["team_id"]==0].drop(columns=drop)
df_home = full_df[full_df["team_id"]==1].drop(columns=drop)

# %%
print(df_away.head())
print(df_home.head())
# Out:
#         x      y  player_id  is_detected frame  timestamp period  \
# 11  40.47   0.24     285188        False    10          0    1.0
# 12  17.85   5.52      51667         True    10          0    1.0
# 13  16.78  -3.67      33697         True    10          0    1.0
# 14  17.03  14.69      51713         True    10          0    1.0
# 15  17.55 -13.60     133498         True    10          0    1.0
#
#     possession_player_id possession_group  team_id
# 11                   NaN             None        0
# 12                   NaN             None        0
# 13                   NaN             None        0
# 14                   NaN             None        0
# 15                   NaN             None        0
#        x      y  player_id  is_detected frame  timestamp period  \
# 0 -39.63  -0.08      51009        False    10          0    1.0
# 1 -19.21  -9.18     176224         True    10          0    1.0
# 2 -21.83   0.47      51649         True    10          0    1.0
# ...

# %%
# drop columns not necessary for ball location
drop_ball = ["x", "y", "player_id", "is_detected", "possession_player_id", "possession_group", "team_id"]
df_ball = full_df.drop(columns=drop_ball).drop_duplicates().reset_index().drop(columns="index")

# %%
df_ball.head()
# Out:
#   frame  timestamp period  ball_x  ball_y  ball_z  is_detected_ball
# 0    10          0    1.0    0.32    0.38    0.13              True
# 1    11          0    1.0    0.54    0.08    0.22              True
# 2    12          0    1.0    0.57   -0.07    0.19              True
# 3    13          0    1.0    0.56   -0.07    0.14              True
# 4    14          0    1.0    0.59   -0.03    0.14              True

# %%
df_ball_test = df_ball.iloc[100:225]
frames = list(df_ball_test["frame"])
print(frames)
# Out:
# [110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234]

# %%
df_home_test = []
df_away_test = []
for frame in frames:
    df_home_test.append(df_home[df_home["frame"]==frame])
    df_away_test.append(df_away[df_away["frame"]==frame])
df_home_test = pd.concat(df_home_test, ignore_index=True)
df_away_test = pd.concat(df_away_test, ignore_index=True)

# %%
df_home_test.head()
# Out:
#        x      y  player_id  is_detected frame  timestamp period  \
# 0 -39.73   3.98      51009        False   110         10    1.0
# 1 -13.64  -1.21     176224         True   110         10    1.0
# 2 -17.11  12.15      51649         True   110         10    1.0
# 3  11.65 -23.18      50983         True   110         10    1.0
# 4  -5.19  26.16     735578         True   110         10    1.0
#
#    possession_player_id possession_group  team_id
# 0              966120.0        away team        1
# 1              966120.0        away team        1
# 2              966120.0        away team        1
# 3              966120.0        away team        1
# 4              966120.0        away team        1

# %%
# First set up the figure, the axis
pitch = Pitch(pitch_type="skillcorner", pitch_length=105, pitch_width=68)
fig, ax = pitch.draw(figsize=(16, 10.4))

# then setup the pitch plot markers we want to animate
marker_kwargs = {'marker': 'o', 'markeredgecolor': 'black', 'linestyle': 'None'}
ball, = ax.plot([], [], ms=6, markerfacecolor='w', zorder=3, **marker_kwargs)
away, = ax.plot([], [], ms=10, markerfacecolor='#b94b75', **marker_kwargs)  # red/maroon
home, = ax.plot([], [], ms=10, markerfacecolor='#7f63b8', **marker_kwargs)  # purple


# animation function
def animate(i):
    """ Function to animate the data. Each frame it sets the data for the players and the ball."""
    # set the ball data with the x and y positions for the ith frame
    ball.set_data(df_ball_test.iloc[i, [3]], df_ball_test.iloc[i, [4]])
    # get the frame id for the ith frame
    frame = df_ball_test.iloc[i, 0]
    # set the player data using the frame id
    x_away = df_away_test.loc[df_away_test["frame"]==frame, 'x']
    y_away = df_away_test.loc[df_away_test["frame"]==frame, 'y']
    x_home = df_home_test.loc[df_home_test["frame"]==frame, 'x']
    y_home = df_home_test.loc[df_home_test["frame"]==frame, 'y']
    away.set_data(x_away, y_away)
    home.set_data(x_home, y_home)

    return ball, away, home

# call the animator, animate so 25 frames per second
anim = animation.FuncAnimation(fig, animate, frames=len(df_ball_test), interval=500, blit=True)
plt.show()
anim.save('example.gif', dpi=150, fps=25, savefig_kwargs={'pad_inches':0, 'facecolor':'#457E29'}, writer="pillow")

# %%
phase = pd.read_csv("../data/matches/1886347/1886347_phases_of_play.csv")

# %%
phase.head()
# Out:
#    index  match_id  frame_start  frame_end time_start time_end  minute_start  \
# 0      0   1886347           28         89    00:01.8  00:07.9             0
# 1      1   1886347           89        107    00:07.9  00:09.7             0
# 2      2   1886347          185        232    00:17.5  00:22.2             0
# 3      3   1886347          232        283    00:22.2  00:27.3             0
# 4      4   1886347          283        301    00:27.3  00:29.1             0
#
#    second_start  duration  period  ...        third_end  penalty_area_end  \
# 0             1       6.1       1  ...     middle_third             False
# 1             7       1.8       1  ...  attacking_third             False
# 2            17       4.7       1  ...  defensive_third             False
# 3            22       5.1       1  ...  attacking_third             False
# 4            27       1.8       1  ...  defensive_third             False
#
# ...

# %%
phase.columns
# Out:
# Index(['index', 'match_id', 'frame_start', 'frame_end', 'time_start',
#        'time_end', 'minute_start', 'second_start', 'duration', 'period',
#        'attacking_side_id', 'team_in_possession_id', 'attacking_side',
#        'team_in_possession_shortname', 'n_player_possessions_in_phase',
#        'team_possession_loss_in_phase', 'team_possession_lead_to_goal',
#        'team_possession_lead_to_shot', 'team_in_possession_phase_type',
#        'team_in_possession_phase_type_id', 'team_out_of_possession_phase_type',
#        'team_out_of_possession_phase_type_id', 'x_start', 'y_start',
#        'channel_id_start', 'channel_start', 'third_id_start', 'third_start',
#        'penalty_area_start', 'x_end', 'y_end', 'channel_id_end', 'channel_end',
#        'third_id_end', 'third_end', 'penalty_area_end',
#        'team_in_possession_width_start', 'team_in_possession_width_end',
#        'team_in_possession_length_start', 'team_in_possession_length_end',
# ...

# %%
print(phase["team_in_possession_phase_type"].value_counts())
# Out:
# team_in_possession_phase_type
# create         156
# chaotic         97
# finish          89
# build_up        63
# direct          23
# set_play        20
# transition       3
# quick_break      3
# Name: count, dtype: int64

# %%
phase[phase["team_in_possession_phase_type"]=="chaotic"].head()
# Out:
#     index  match_id  frame_start  frame_end time_start time_end  minute_start  \
# 4       4   1886347          283        301    00:27.3  00:29.1             0
# 12     12   1886347          974       1025    01:36.4  01:41.5             1
# 20     20   1886347         1466       1546    02:25.6  02:33.6             2
# 23     23   1886347         1612       1655    02:40.2  02:44.5             2
# 31     31   1886347         2838       2857    04:42.8  04:44.7             4
#
#     second_start  duration  period  ...        third_end  penalty_area_end  \
# 4             27       1.8       1  ...  defensive_third             False
# 12            36       5.1       1  ...  attacking_third             False
# 20            25       8.0       1  ...  attacking_third             False
# 23            40       4.3       1  ...  attacking_third             False
# 31            42       1.9       1  ...     middle_third             False
#
# ...

# %%
df2850 = full_df[full_df["frame"]==2850] # inbetween 2838 and 2857 -> chaotic build up
df2850.head()
# Out:
#            x      y  player_id  is_detected frame  timestamp period  \
# 59708 -29.59  -6.63      51009        False  2850        284    1.0
# 59709   5.01 -25.19     176224         True  2850        284    1.0
# 59710   9.47 -22.31      51649         True  2850        284    1.0
# 59711  11.26 -29.68      50983         True  2850        284    1.0
# 59712   9.93  -9.48     735578        False  2850        284    1.0
#
#        possession_player_id possession_group  ball_x  ball_y  ball_z  \
# 59708                   NaN        home team    15.2  -27.52    2.57
# 59709                   NaN        home team    15.2  -27.52    2.57
# 59710                   NaN        home team    15.2  -27.52    2.57
# 59711                   NaN        home team    15.2  -27.52    2.57
# 59712                   NaN        home team    15.2  -27.52    2.57
#
#        is_detected_ball  team_id
# 59708              True        1
# 59709              True        1
# 59710              True        1
# ...

# %%
# get tracking stats
x1 = df2850[df2850["team_id"]==1]["x"]
y1 = df2850[df2850["team_id"]==1]["y"]
x2 = df2850[df2850["team_id"]!=1]["x"]
y2 = df2850[df2850["team_id"]!=1]["y"]

# %%
# get individual list of each column
ball_x = df2850["ball_x"].iloc[0]
ball_y = df2850["ball_y"].iloc[0]
team_id = df2850["team_id"].tolist()

# %%
# plot voronoi of snapshot
p = Pitch(pitch_type="skillcorner", pitch_length=105, pitch_width=68, axis=True, label=True)
fig, ax = p.draw(figsize=(12,8))

# Plot Voronoi
team1, team2 = p.voronoi(x2, y2, team_id[11:23])
t1 = p.polygon(team1, ax=ax, fc='orange', ec='white', lw=3, alpha=0.4)
t2 = p.polygon(team2, ax=ax, fc='dodgerblue', ec='white', lw=3, alpha=0.4)

# Plot players
sc1 = p.scatter(x1, y1, c='orange', s=80, ec='k', ax=ax)
sc2 = p.scatter(x2, y2, c='dodgerblue', s=80, ec='k', ax=ax)
ball = p.scatter(ball_x, ball_y, c='red', s=60, ec='k', ax=ax)
fig.suptitle('Voronoi for chaotic build up', fontsize=16)
plt.savefig("../voronoi/chaotic.png")
plt.show()

# %%
phase[phase["team_in_possession_phase_type"]=="create"].iloc[50:55]
# Out:
#      index  match_id  frame_start  frame_end time_start time_end  \
# 129    129   1886347        11879      12012    19:46.9  20:00.2
# 132    132   1886347        12212      12413    20:20.2  20:40.3
# 134    134   1886347        12414      12468    20:40.4  20:45.8
# 136    136   1886347        12642      12736    21:03.2  21:12.6
# 138    138   1886347        13006      13083    21:39.6  21:47.3
#
#      minute_start  second_start  duration  period  ...        third_end  \
# 129            19            46      13.3       1  ...  attacking_third
# 132            20            20      20.1       1  ...     middle_third
# 134            20            40       5.4       1  ...  defensive_third
# 136            21             3       9.4       1  ...  attacking_third
# 138            21            39       7.7       1  ...  attacking_third
#
#      penalty_area_end team_in_possession_width_start  \
# 129             False                          45.40
# ...

# %% [markdown]
# between 5782 and 5798

# %%
df2850 = full_df[full_df["frame"]==12400] # inbetween 2838 and 2857 -> chaotic build up
print(df2850.head())

# get tracking stats
x1 = df2850[df2850["team_id"]==1]["x"]
y1 = df2850[df2850["team_id"]==1]["y"]
x2 = df2850[df2850["team_id"]!=1]["x"]
y2 = df2850[df2850["team_id"]!=1]["y"]

# get individual list of each column
ball_x = df2850["ball_x"].iloc[0]
ball_y = df2850["ball_y"].iloc[0]
team_id = df2850["team_id"].tolist()

# plot voronoi of snapshot
p = Pitch(pitch_type="skillcorner", pitch_length=105, pitch_width=68, axis=True, label=True)
fig, ax = p.draw(figsize=(12,8))

# Plot Voronoi
team1, team2 = p.voronoi(x2, y2, team_id[11:23])
t1 = p.polygon(team1, ax=ax, fc='orange', ec='white', lw=3, alpha=0.4)
t2 = p.polygon(team2, ax=ax, fc='dodgerblue', ec='white', lw=3, alpha=0.4)

# Plot players
sc1 = p.scatter(x1, y1, c='orange', s=80, ec='k', ax=ax)
sc2 = p.scatter(x2, y2, c='dodgerblue', s=80, ec='k', ax=ax)
ball = p.scatter(ball_x, ball_y, c='red', s=60, ec='k', ax=ax)
fig.suptitle('Voronoi for "create" build up', fontsize=16)
plt.savefig("../voronoi/create.jpg")
plt.show()
# Out:
#             x      y  player_id  is_detected  frame  timestamp period  \
# 234762 -46.60  -4.49      51009         True  12400       1239    1.0
# 234763 -38.03 -25.31     176224        False  12400       1239    1.0
# 234764 -37.04  -0.92      51649         True  12400       1239    1.0
# 234765 -16.15 -28.46      50983         True  12400       1239    1.0
# 234766 -33.69  11.77     735578         True  12400       1239    1.0
#
#         possession_player_id possession_group  ball_x  ball_y  ball_z  \
# 234762                   NaN        home team  -24.84  -22.49    0.06
# 234763                   NaN        home team  -24.84  -22.49    0.06
# 234764                   NaN        home team  -24.84  -22.49    0.06
# 234765                   NaN        home team  -24.84  -22.49    0.06
# 234766                   NaN        home team  -24.84  -22.49    0.06
#
#         is_detected_ball  team_id
# 234762              True        1
# 234763              True        1
# ...

# %%
phase[phase["team_in_possession_phase_type"]=="finish"].iloc[20:25]
# Out:
#      index  match_id  frame_start  frame_end time_start time_end  \
# 103    103   1886347         9543       9568    15:53.3  15:55.8
# 105    105   1886347         9594       9627    15:58.4  16:01.7
# 117    117   1886347        10683      10754    17:47.3  17:54.4
# 119    119   1886347        10804      10851    17:59.4  18:04.1
# 128    128   1886347        11857      11879    19:44.7  19:46.9
#
#      minute_start  second_start  duration  period  ...        third_end  \
# 103            15            53       2.5       1  ...     middle_third
# 105            15            58       3.3       1  ...     middle_third
# 117            17            47       7.1       1  ...  attacking_third
# 119            17            59       4.7       1  ...  attacking_third
# 128            19            44       2.2       1  ...     middle_third
#
#      penalty_area_end team_in_possession_width_start  \
# 103             False                          44.34
# ...

# %%
df2850 = full_df[full_df["frame"]==10820] # inbetween 2838 and 2857 -> chaotic build up
print(df2850.head())

# get tracking stats
x1 = df2850[df2850["team_id"]==1]["x"]
y1 = df2850[df2850["team_id"]==1]["y"]
x2 = df2850[df2850["team_id"]!=1]["x"]
y2 = df2850[df2850["team_id"]!=1]["y"]

# get individual list of each column
ball_x = df2850["ball_x"].iloc[0]
ball_y = df2850["ball_y"].iloc[0]
team_id = df2850["team_id"].tolist()

# plot voronoi of snapshot
p = Pitch(pitch_type="skillcorner", pitch_length=105, pitch_width=68, axis=True, label=True)
fig, ax = p.draw(figsize=(12,8))

# Plot Voronoi
team1, team2 = p.voronoi(x2, y2, team_id[11:23])
t1 = p.polygon(team1, ax=ax, fc='orange', ec='white', lw=3, alpha=0.4)
t2 = p.polygon(team2, ax=ax, fc='dodgerblue', ec='white', lw=3, alpha=0.4)

# Plot players
sc1 = p.scatter(x1, y1, c='orange', s=80, ec='k', ax=ax)
sc2 = p.scatter(x2, y2, c='dodgerblue', s=80, ec='k', ax=ax)
ball = p.scatter(ball_x, ball_y, c='red', s=60, ec='k', ax=ax)
fig.suptitle('Voronoi for finish', fontsize=16)
plt.savefig("../voronoi/finish.png")
plt.show()
# Out:
#             x      y  player_id  is_detected  frame  timestamp period  \
# 215314 -29.89   1.14      51009        False  10820       1081    1.0
# 215315   2.25  -1.37     176224        False  10820       1081    1.0
# 215316   3.78   5.31      51649        False  10820       1081    1.0
# 215317  36.16   3.80      50983         True  10820       1081    1.0
# 215318  14.37  14.45     735578        False  10820       1081    1.0
#
#         possession_player_id possession_group  ball_x  ball_y  ball_z  \
# 215314                   NaN        home team   36.81    9.61    0.75
# 215315                   NaN        home team   36.81    9.61    0.75
# 215316                   NaN        home team   36.81    9.61    0.75
# 215317                   NaN        home team   36.81    9.61    0.75
# 215318                   NaN        home team   36.81    9.61    0.75
#
#         is_detected_ball  team_id
# 215314              True        1
# 215315              True        1
# ...

# %%
phase[phase["team_in_possession_phase_type"]=="build_up"].iloc[20:25]
# Out:
#      index  match_id  frame_start  frame_end time_start time_end  \
# 124    124   1886347        11669      11774    19:25.9  19:36.4
# 126    126   1886347        11778      11840    19:36.8  19:43.0
# 135    135   1886347        12468      12642    20:45.8  21:03.2
# 157    157   1886347        15480      15572    25:47.0  25:56.2
# 159    159   1886347        15626      15708    26:01.6  26:09.8
#
#      minute_start  second_start  duration  period  ...        third_end  \
# 124            19            25      10.5       1  ...  defensive_third
# 126            19            36       6.2       1  ...  defensive_third
# 135            20            45      17.4       1  ...  defensive_third
# 157            25            47       9.2       1  ...  defensive_third
# 159            26             1       8.2       1  ...  defensive_third
#
#      penalty_area_end team_in_possession_width_start  \
# 124             False                          36.26
# ...

# %%
df2850 = full_df[full_df["frame"]==12600] # inbetween 2838 and 2857 -> chaotic build up
print(df2850.head())

# get tracking stats
x1 = df2850[df2850["team_id"]==1]["x"]
y1 = df2850[df2850["team_id"]==1]["y"]
x2 = df2850[df2850["team_id"]!=1]["x"]
y2 = df2850[df2850["team_id"]!=1]["y"]

# get individual list of each column
ball_x = df2850["ball_x"].iloc[0]
ball_y = df2850["ball_y"].iloc[0]
team_id = df2850["team_id"].tolist()

# plot voronoi of snapshot
p = Pitch(pitch_type="skillcorner", pitch_length=105, pitch_width=68, axis=True, label=True)
fig, ax = p.draw(figsize=(12,8))

# Plot Voronoi
team1, team2 = p.voronoi(x1, y1, team_id[0:11])
t1 = p.polygon(team1, ax=ax, fc='orange', ec='white', lw=3, alpha=0.4)
t2 = p.polygon(team2, ax=ax, fc='dodgerblue', ec='white', lw=3, alpha=0.4)

# Plot players
sc1 = p.scatter(x1, y1, c='orange', s=80, ec='k', ax=ax)
sc2 = p.scatter(x2, y2, c='dodgerblue', s=80, ec='k', ax=ax)
ball = p.scatter(ball_x, ball_y, c='red', s=60, ec='k', ax=ax)
fig.suptitle('Voronoi for build up', fontsize=16)
plt.savefig("../voronoi/build_up.png")
plt.show()
# Out:
#             x      y  player_id  is_detected  frame  timestamp period  \
# 239162 -34.99  -0.92      51009        False  12600       1259    1.0
# 239163  -8.24  -8.13     176224        False  12600       1259    1.0
# 239164  -8.77   1.39      51649        False  12600       1259    1.0
# 239165  -7.37 -19.21      50983        False  12600       1259    1.0
# 239166  -6.88  12.74     735578        False  12600       1259    1.0
#
#         possession_player_id possession_group  ball_x  ball_y  ball_z  \
# 239162              285188.0        home team   32.34   -1.52    0.21
# 239163              285188.0        home team   32.34   -1.52    0.21
# 239164              285188.0        home team   32.34   -1.52    0.21
# 239165              285188.0        home team   32.34   -1.52    0.21
# 239166              285188.0        home team   32.34   -1.52    0.21
#
#         is_detected_ball  team_id
# 239162              True        1
# 239163              True        1
# ...
